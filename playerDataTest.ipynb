# %%
from nba_api.stats.endpoints import leaguedashplayerstats

player_stats = leaguedashplayerstats.LeagueDashPlayerStats(per_mode_detailed="PerGame")
df = player_stats.get_data_frames()[0]

print(df.shape)
print(df.columns)
print(df.isnull().sum())
df.head()
# Out:
# (539, 66)
# Index(['PLAYER_ID', 'PLAYER_NAME', 'NICKNAME', 'TEAM_ID', 'TEAM_ABBREVIATION',
#        'AGE', 'GP', 'W', 'L', 'W_PCT', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M',
#        'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST',
#        'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS',
#        'NBA_FANTASY_PTS', 'DD2', 'TD3', 'WNBA_FANTASY_PTS', 'GP_RANK',
#        'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'FGM_RANK', 'FGA_RANK',
#        'FG_PCT_RANK', 'FG3M_RANK', 'FG3A_RANK', 'FG3_PCT_RANK', 'FTM_RANK',
#        'FTA_RANK', 'FT_PCT_RANK', 'OREB_RANK', 'DREB_RANK', 'REB_RANK',
#        'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK',
#        'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK', 'NBA_FANTASY_PTS_RANK',
#        'DD2_RANK', 'TD3_RANK', 'WNBA_FANTASY_PTS_RANK'],
#       dtype='object')
# PLAYER_ID                0
# PLAYER_NAME              0
# NICKNAME                 0
# TEAM_ID                  0
# TEAM_ABBREVIATION        0
#                         ..
# PLUS_MINUS_RANK          0
# NBA_FANTASY_PTS_RANK     0
# DD2_RANK                 0
# TD3_RANK                 0
# WNBA_FANTASY_PTS_RANK    0
# Length: 66, dtype: int64
#    PLAYER_ID    PLAYER_NAME NICKNAME     TEAM_ID TEAM_ABBREVIATION   AGE  GP  \
# 0    1630639    A.J. Lawson     A.J.  1610612742               DAL  22.0  15
# 1    1631260       AJ Green       AJ  1610612749               MIL  23.0  35
# 2    1631100     AJ Griffin       AJ  1610612737               ATL  19.0  72
# 3     203932   Aaron Gordon    Aaron  1610612743               DEN  27.0  68
# 4    1628988  Aaron Holiday    Aaron  1610612737               ATL  26.0  63
#
#     W   L  W_PCT  ...  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# 0   5  10  0.333  ...       491        358      475       457       429
# 1  27   8  0.771  ...       491        498      454       518       392
# 2  34  38  0.472  ...       372        268      394       422       217
# 3  45  23  0.662  ...        65         32      205        58        82
# 4  32  31  0.508  ...       345        315      377       356       415
#
#    PLUS_MINUS_RANK  NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  \
# 0              462                   482       253        39
# 1              309                   455       253        39
# 2              169                   287       253        39
# 3                4                    77        56        39
# 4              212                   413       253        39
#
#    WNBA_FANTASY_PTS_RANK
# 0                    466
# 1                    436
# 2                    273
# 3                     89
# 4                    416
#
# [5 rows x 66 columns]

# %%
df = df[['PLAYER_ID', 'PLAYER_NAME', 'TEAM_ABBREVIATION', 'GP', 'PTS', 'REB', 'AST', 'STL', 'BLK', 'FG_PCT', 'FT_PCT', 'FG3_PCT', 'FG3A']]
df = df[(df['GP'] > 30)]
df = df.sort_values('FG3A', ascending=False)
print(df["TEAM_ABBREVIATION"].unique())
df.head()
# Out:
# ['GSW' 'POR' 'CHA' 'CLE' 'BOS' 'TOR' 'IND' 'DAL' 'NYK' 'LAL' 'MIA' 'UTA'
#  'LAC' 'WAS' 'DEN' 'MIN' 'HOU' 'NOP' 'PHI' 'CHI' 'MEM' 'SAS' 'SAC' 'ATL'
#  'BKN' 'MIL' 'PHX' 'DET' 'OKC' 'ORL']
#      PLAYER_ID       PLAYER_NAME TEAM_ABBREVIATION  GP   PTS  REB  AST  STL  \
# 471     201939     Stephen Curry               GSW  56  29.4  6.1  6.3  0.9
# 90      203081    Damian Lillard               POR  58  32.2  4.8  7.3  0.9
# 320     202691     Klay Thompson               GSW  69  21.9  4.1  2.4  0.7
# 328    1630163       LaMelo Ball               CHA  36  23.3  6.4  8.4  1.3
# 132    1628378  Donovan Mitchell               CLE  68  28.3  4.3  4.4  1.5
#
#      BLK  FG_PCT  FT_PCT  FG3_PCT  FG3A
# 471  0.4   0.493   0.915    0.427  11.4
# 90   0.3   0.463   0.914    0.371  11.3
# 320  0.4   0.436   0.879    0.412  10.6
# 328  0.3   0.411   0.843    0.376  10.6
# 132  0.4   0.484   0.867    0.386   9.3
